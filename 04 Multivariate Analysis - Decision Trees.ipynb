# %%
pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jupyter in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from -r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: notebook in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from -r requirements.txt (line 2)) (7.5.5)
# Requirement already satisfied: pandas in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from -r requirements.txt (line 3)) (3.0.2)
# Requirement already satisfied: numpy in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from -r requirements.txt (line 4)) (2.4.4)
# Requirement already satisfied: scipy in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from -r requirements.txt (line 5)) (1.17.1)
# Requirement already satisfied: matplotlib in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from -r requirements.txt (line 6)) (3.10.8)
# Requirement already satisfied: seaborn in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from -r requirements.txt (line 7)) (0.13.2)
# Requirement already satisfied: scikit-learn in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from -r requirements.txt (line 8)) (1.8.0)
# Requirement already satisfied: graphviz in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from -r requirements.txt (line 9)) (0.21)
# Requirement already satisfied: dtreeviz in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from -r requirements.txt (line 10)) (2.3.2)
# Requirement already satisfied: opencv-python in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from -r requirements.txt (line 11)) (4.13.0.92)
# Requirement already satisfied: ultralytics in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from -r requirements.txt (line 12)) (8.4.41)
# Requirement already satisfied: jupyter-console in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter->-r requirements.txt (line 1)) (6.6.3)
# Requirement already satisfied: nbconvert in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter->-r requirements.txt (line 1)) (7.17.1)
# Requirement already satisfied: ipykernel in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter->-r requirements.txt (line 1)) (7.2.0)
# Requirement already satisfied: ipywidgets in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter->-r requirements.txt (line 1)) (8.1.8)
# Requirement already satisfied: jupyterlab in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter->-r requirements.txt (line 1)) (4.5.6)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from notebook->-r requirements.txt (line 2)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from notebook->-r requirements.txt (line 2)) (2.28.0)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from notebook->-r requirements.txt (line 2)) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from notebook->-r requirements.txt (line 2)) (6.5.5)
# Requirement already satisfied: anyio>=3.1.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (4.13.0)
# Requirement already satisfied: argon2-cffi>=21.1 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (5.9.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (5.10.4)
# Requirement already satisfied: packaging>=22.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (26.1)
# Requirement already satisfied: prometheus-client>=0.9 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (0.25.0)
# Requirement already satisfied: pywinpty>=2.0.1 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: pyzmq>=24 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (1.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (2.3.1)
# Requirement already satisfied: setuptools>=41.1.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 1)) (81.0.0)
# Requirement already satisfied: certifi in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: idna in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (3.12)
# Requirement already satisfied: h11>=0.16 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: babel>=2.10 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyterlab-server<3,>=2.28.0->notebook->-r requirements.txt (line 2)) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyterlab-server<3,>=2.28.0->notebook->-r requirements.txt (line 2)) (0.14.0)
# Requirement already satisfied: jsonschema>=4.18.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyterlab-server<3,>=2.28.0->notebook->-r requirements.txt (line 2)) (4.26.0)
# Requirement already satisfied: requests>=2.31 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyterlab-server<3,>=2.28.0->notebook->-r requirements.txt (line 2)) (2.33.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pandas->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pandas->-r requirements.txt (line 3)) (2026.1)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib->-r requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib->-r requirements.txt (line 6)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib->-r requirements.txt (line 6)) (1.5.0)
# Requirement already satisfied: pillow>=8 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib->-r requirements.txt (line 6)) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib->-r requirements.txt (line 6)) (3.3.2)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from scikit-learn->-r requirements.txt (line 8)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from scikit-learn->-r requirements.txt (line 8)) (3.6.0)
# Requirement already satisfied: colour in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from dtreeviz->-r requirements.txt (line 10)) (0.1.5)
# Requirement already satisfied: pyyaml>=5.3.1 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ultralytics->-r requirements.txt (line 12)) (6.0.3)
# Requirement already satisfied: torch>=1.8.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ultralytics->-r requirements.txt (line 12)) (2.11.0)
# Requirement already satisfied: torchvision>=0.9.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ultralytics->-r requirements.txt (line 12)) (0.26.0)
# Requirement already satisfied: psutil>=5.8.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ultralytics->-r requirements.txt (line 12)) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ultralytics->-r requirements.txt (line 12)) (1.40.0)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ultralytics->-r requirements.txt (line 12)) (2.0.18)
# Requirement already satisfied: argon2-cffi-bindings in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (25.1.0)
# Requirement already satisfied: comm>=0.1.1 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (9.12.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ipykernel->jupyter->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: colorama>=0.4.4 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: wcwidth in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.8.6)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook->-r requirements.txt (line 2)) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook->-r requirements.txt (line 2)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook->-r requirements.txt (line 2)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook->-r requirements.txt (line 2)) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (4.9.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (4.1.0)
# Requirement already satisfied: rfc3339-validator in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (0.1.1)
# Requirement already satisfied: fqdn in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (1.5.1)
# Requirement already satisfied: isoduration in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: uri-template in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 1)) (6.3.0)
# Requirement already satisfied: defusedxml in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from nbconvert->jupyter->-r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: webencodings in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (2.21.2)
# Requirement already satisfied: polars-runtime-32==1.40.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from polars>=0.20.0->ultralytics->-r requirements.txt (line 12)) (1.40.0)
# Requirement already satisfied: six>=1.5 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook->-r requirements.txt (line 2)) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook->-r requirements.txt (line 2)) (2.6.3)
# Requirement already satisfied: lark>=1.2.2 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (3.0.1)
# Requirement already satisfied: pure-eval in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: filelock in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 12)) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 12)) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 12)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 12)) (3.6.1)
# Requirement already satisfied: fsspec>=0.8.5 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 12)) (2026.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics->-r requirements.txt (line 12)) (1.3.0)
# Requirement already satisfied: cffi>=1.0.1 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 1)) (2.8.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 1)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 1)) (3.0.16)
# Requirement already satisfied: arrow>=0.15.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 2)) (1.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Multivariate analysis: Modeling

# %% [markdown]
# ![](https://media.geeksforgeeks.org/wp-content/uploads/20240919170522/supervised-vs-reinforcement-vs-unsupervised.webp)

# %% [markdown]
# ![](https://docs.microsoft.com/en-us/azure/machine-learning/team-data-science-process/media/overview/tdsp-lifecycle2.png "Data Science Lifecycle")

# %% [markdown]
# Interesting sources:
# - https://learn.datacamp.com/courses/machine-learning-with-tree-based-models-in-python
# - https://www.datacamp.com/community/tutorials/decision-tree-classification-python

# %% [markdown]
# We have seen that we can uncover correlations by using bivariate analyis. This also raises the question: If we extract information from multiple columns (Multivariate analysis), could we use these correlations to calculate/predict the value of a column for rows that do not yet have a value?
#
# For example:
# - Can we calculate if a customer will churn (= We lose the customer)?
# - Can we calculate if a customer would use a certain product? (Product recommendation)
# - Can we calculate if a mail is spam or not?
# - Can we calculate if a financial transaction is fraudulent or not?
# - Can we calculate if a customer will be able to pay back their loan or not?
# - Can we calculate the price people are willing to pay for a house?
# - Can we calculate the salary a student will earn in the future?
# - ...
#
# Just as we used math/statistics to support to explore the data one column at a time (Univariate) and per combination of two columns (Bivariate analysis), we will use machine learning algorithms to extract information across multiple columns (Multivariate analysis) and to build data products.
#
# Machine learning is:
# - Machine learning is a method of data analysis that automates analytical model building. It is a branch of artificial intelligence based on the idea that systems can learn from data, identify patterns and make decisions with minimal human intervention. (https://www.sas.com/en_us/insights/analytics/machine-learning.html#:~:text=Machine%20learning%20is%20a%20method,decisions%20with%20minimal%20human%20intervention.)
# - Machine learning (ML) is the study of computer algorithms that improve automatically through experience.[1] It is seen as a part of artificial intelligence. Machine learning algorithms build a model based on sample data, known as "training data", in order to make predictions or decisions without being explicitly programmed to do so.[2] Machine learning algorithms are used in a wide variety of applications, such as email filtering and computer vision, where it is difficult or unfeasible to develop conventional algorithms to perform the needed tasks. (https://en.wikipedia.org/wiki/Machine_learning)
#
# Examples of data products could include:
# - A product recommender
# - A customer churn predictor
# - A mail labeler (Primary, promotion, social, spam, etc.)
# - Sentiment analyser for social media messages
# - ...

# %% [markdown]
# ![](https://miro.medium.com/max/1204/1*qYoU2VTBsORAfhkfiluURQ.png)

# %% [markdown]
# We will refer to the column that we are trying to calculate as the <b>target variable</b>. The columns used for this calculation will be refered to as the <b>feature variables</b>.
#
# For example, if we want to predict a person's shoe size based on their body length:
# - The shoe size is the target variable
# - The body length is the feature variable
#
# Extra info: The terms 'target' and 'feature' are borrowed from the field of Machine Learning. In the field of statistics, we refer to the target variable as the dependent variable and we refer to the feature variables as the independent variables.

# %% [markdown]
# # Classification

# %% [markdown]
# When the target variable is a categorical variable then we refer to this task as a classification task.
#
# Examples of classification tasks:
# - Predict if a customer will churn.
# - Predict if a customer will use a specific product.
# - Label mails as spam.
# - Label financial transactions as fraudulent.
# - Label a social media message as positive, neutral or negative.
# - Predict if a customer of the bank will be able to pay back the loan.
#
# Examples of machine learning algorithms that we could use for classification:
# - Decision trees
# - Random forests
# - Logistic regression
# - Neural networks
# - Naive bayes

# %%
import seaborn as sns
import pandas as pd

iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ![](https://miro.medium.com/max/1000/1*Hh53mOF4Xy4eORjLilKOwA.png "Iris dataset")

# %% [markdown]
# ## Training the model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
features= ['sepal_length', 'petal_length']
dt = DecisionTreeClassifier(max_depth = 2) # Increase max_depth to see effect in the plot
dt.fit(iris[features], iris['species'])
# Out:
# DecisionTreeClassifier(max_depth=2)

# %% [markdown]
# This Python code trains a **Decision Tree Classifier** on a subset of the famous Iris dataset, using only two features: 'sepal_length' and 'petal_length'. **Only these will be used to train the model**. It creates a decision tree classifier with a **maximum depth of 5**, meaning the tree will be allowed to split at most 5 times from the root to a leaf. This limits its complexity and helps prevent overfitting.
#
# It trains (fits) the decision tree on the selected features and the **target label 'species'**. It learns to classify the type of Iris flower (setosa, versicolor, virginica) based on 'sepal_length' and 'petal_length'.

# %% [markdown]
# `conda install -c anaconda graphviz`
# `conda install -c anaconda python-graphviz`
# `conda install -c anaconda pydot`
# If the code below still does not work, install from here: (https://graphviz.org/download/)

# %%
pip install graphviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: graphviz in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (0.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn import tree
import graphviz

def plot_tree_classification(model, features, class_names):
    # Generate plot data
    dot_data = tree.export_graphviz(model, out_file=None, 
                          feature_names=features,  
                          class_names=class_names,  
                          filled=True, rounded=True,  
                          special_characters=True)  

    # Turn into graph using graphviz
    graph = graphviz.Source(dot_data)  

    # Write out a pdf
    graph.render("decision_tree")

    # Display in the notebook
    return graph

# %%
import numpy as np
plot_tree_classification(dt, features, np.sort(iris.species.unique()))

# %% [markdown]
# **What do you see here?**
#
# Let's take a look at the first node:
#
# samples = 150: all samples from the dataset.
# value = [50, 50, 50]: 50 samples each from setosa, versicolor, and virginica.
# gini = 0.667: high impurity (which makes sense, since the classes are perfectly balanced).
# petal_length ≤ 2.45: this is the first split criterion.
#
# class = the predicted class.
# The class with the highest number of samples at that node.
# But at the first node, all classes are equally represented ([50, 50, 50]), so technically the model is just picking one arbitrarily — probably the first in lexicographic order, which is: setosa, versicolor, virginica
# So, it's not a prediction, just a default label when there's a tie.

# %% [markdown]
# ## Evaluating the model

# %%
predictions = dt.predict(iris[features])

# %%
predictions
# Out:
# array(['setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'versicolor', 'versicolor', 'virginica',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'virginica', 'versicolor', 'virginica', 'versicolor',
#        'versicolor', 'versicolor', 'virginica', 'virginica', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'virginica', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'versicolor', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica'], dtype=object)

# %% [markdown]
# **What this does:**
#
# It uses your trained decision tree model (dt) to make predictions on the dataset iris[features], which contains only the two features:
# 'sepal_length' and 'petal_length'.
#
# **🧠 What kind of predictions?**
#
# The model outputs the predicted species (e.g., 'setosa', 'versicolor', 'virginica') for each row in the dataset — based on the decision rules it learned during training.

# %%
def calculate_accuracy(predictions, actuals):
    if(len(predictions) != len(actuals)):
        raise Exception("The amount of predictions did not equal the amount of actuals")
    
    return (predictions == actuals).sum() / len(actuals)

# %%
calculate_accuracy(predictions, iris.species)
# Out:
# np.float64(0.9533333333333334)

# %% [markdown]
# This function **calculate_accuracy(predictions, actuals)** computes the classification accuracy of your model's predictions compared to the actual (true) labels.

# %% [markdown]
# ### Test/train split

# %%
from sklearn.model_selection import train_test_split

# %%
iris_train, iris_test = train_test_split(iris, test_size=0.3, random_state=42, stratify=iris['species'])
print(iris_train.shape, iris_test.shape)
# Out:
# (105, 5) (45, 5)

# %% [markdown]
# **Why Test/Train split?**
#
# Splitting the dataset allows you to train the model on one part (training set) and evaluate it on another (test set).
# This helps you simulate how the model performs on unseen, real-world data. It prevents **overfitting**, where the model memorizes the training data but fails on new data.
#
# The **stratify** option ensures that each class is proportionally represented in both the training and test sets. This is important for balanced model training and fair evaluation.
# **random_state ensures reproducibility**, so you get the same split each time you run the code.
# **A 70/30 split (test_size=0.3)** is a common and balanced choice for small datasets like Iris.

# %%
features= ['sepal_length', 'sepal_width']
dt_classification = DecisionTreeClassifier(max_depth = 3) # Increase max_depth to see effect in the plot
dt_classification.fit(iris_train[features], iris_train['species'])
# Out:
# DecisionTreeClassifier(max_depth=3)

# %% [markdown]
# ### Overfitting

# %%
predictionsOnTrainset = dt_classification.predict(iris_train[features])
predictionsOnTestset = dt_classification.predict(iris_test[features])

accuracyTrain = calculate_accuracy(predictionsOnTrainset, iris_train.species)
accuracyTest = calculate_accuracy(predictionsOnTestset, iris_test.species)

print("Accuracy on training set " + str(accuracyTrain))
print("Accuracy on test set " + str(accuracyTest))
# Out:
# Accuracy on training set 0.8380952380952381
# Accuracy on test set 0.7333333333333333

# %% [markdown]
# **Results Summary**
#
# Training Accuracy: 83.8%
# Test Accuracy: 73.3%
#
# **What this means**
#
# Your model performs reasonably well on the training data.
# The lower test accuracy suggests the model is not generalizing perfectly to unseen data.
# The ~10% drop in accuracy is a sign of mild overfitting — the model may have learned some patterns specific to the training data that don't hold in the test set.

# %% [markdown]
# ### Saving your model

# %% [markdown]
# Training a machine learning model can be a time-consuming process—sometimes taking hours or even days—especially when working with large datasets. Once the model is trained and ready for production, it's inefficient and unnecessary to retrain it every time new data becomes available. To address this, we typically save the trained model to a file so it can be reused later without retraining. This is known as model serialization. There are several tools available for this purpose, such as joblib, pickle, or plk (short for .pltk format). In this case, we use the .pltk format to store the trained model, which allows us to quickly load and deploy it whenever needed.

# %%
import pickle

# Save the model
with open('Decisiontree_95%.pkl', 'wb') as f:
    pickle.dump(dt_classification, f)

# %% [markdown]
# ## Portfolio assignment 15
# 30 min: Train a decision tree to predict the species of a **penguin** based on their characteristics.
# - Prepare the data:
#     - <b>Note</b>: Some machine learning algorithms can not handle missing values. You will either need to:
#          - replace missing values (with the mean or most popular value). For replacing missing values you can use .fillna(\<value\>) https://pandas.pydata.org/docs/reference/api/pandas.Series.fillna.html
#          - remove rows with missing data.  You can remove rows with missing data with .dropna() https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html
# - Split the penguin dataset into a train (70%) and test (30%) set.
# - Use the train set to fit a DecisionTreeClassifier. You are free to to choose which columns you want to use as feature variables and you are also free to choose the max_depth of the tree.
# - Use your decision tree model to make predictions for both the train and test set.

# %%
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins_train, penguins_test = train_test_split(penguins, test_size=0.3, random_state=42, stratify=penguins['species'])
print(penguins_train.shape, penguins_test.shape)
# Out:
# (240, 7) (104, 7)

# %%
features= ['bill_length_mm', 'flipper_length_mm']
dt_classification = DecisionTreeClassifier(max_depth = 3) # Increase max_depth to see effect in the plot
dt_classification.fit(penguins_train[features], penguins_train['species'])
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
predictionsOnTrainset = dt_classification.predict(penguins_train[features])
predictionsOnTestset = dt_classification.predict(penguins_test[features])

accuracyTrain = calculate_accuracy(predictionsOnTrainset, penguins_train.species)
accuracyTest = calculate_accuracy(predictionsOnTestset, penguins_test.species)

print("Accuracy on training set " + str(accuracyTrain))
print("Accuracy on test set " + str(accuracyTest))
# Out:
# Accuracy on training set 0.9416666666666667
# Accuracy on test set 0.9615384615384616

# %%
plot_tree_classification(dt_classification, features, np.sort(penguins_train['species'].unique()))

# %%
plot_tree_classification(dt_classification, features, np.sort(penguins_test['species'].unique()))

# %%
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# ![](https://i.imgur.com/0v1CGNV.png)<br>
# - Calculate the accuracy for both the train set predictions and test set predictions
# - Is the accurracy different? Did you expect this difference?
# - Use the plot_tree_classification function above to create a plot of the decision tree. Take a few minutes to analyse the decision tree. Do you understand the tree?
# - Which depth and features did you add per cycle?
# - Optional: Perform the same tasks but try to predict the sex of the pinguin based on the other columns<br>
# <br>
#
# Findings: ...

# %% [markdown]
# ## Portfolio assignment 16
# 30 min: Train a decision tree to predict one of the categorical columns of your **own** dataset.
# - Prepare the data:<br>
#     - <b>Note</b>: Some machine learning algorithms can not handle missing values. You will either need to:
#          - replace missing values (with the mean or most popular value). For replacing missing values you can use .fillna(\<value\>) https://pandas.pydata.org/docs/reference/api/pandas.Series.fillna.html
#          - remove rows with missing data.  You can remove rows with missing data with .dropna() https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html <br>
# - Split your dataset into a train (70%) and test (30%) set.
# - Use the train set to fit a DecisionTreeClassifier. You are free to to choose which columns you want to use as feature variables and you are also free to choose the max_depth of the tree.
# - Use your decision tree model to make predictions for both the train and test set.<br>
# <br>
#
# ![](https://i.imgur.com/0v1CGNV.png)<br>
# - Calculate the accuracy for both the train set predictions and test set predictions.
# - Is the accurracy different? Did you expect this difference?
# - Use the plot_tree function above to create a plot of the decision tree. Take a few minutes to analyse the decision tree. Do you understand the tree?
# - Which depth and features did you add per cycle?<br>
# <br>
#
# Findings: ...

# %%
import pandas as pd
topRatedAnime = pd.read_csv('top_anime_dataset.csv', sep=',')
topRatedAnime.head()
# Out:
#    mal_id                             title  \
# 0   52991                 Sousou no Frieren
# 1   59978      Sousou no Frieren 2nd Season
# 2    5114  Fullmetal Alchemist: Brotherhood
# 3   57555      Chainsaw Man Movie: Reze-hen
# 4    9253                       Steins;Gate
#
#                             title_english   type        source  episodes  \
# 0           Frieren: Beyond Journey's End     TV         Manga      28.0
# 1  Frieren: Beyond Journey's End Season 2     TV         Manga      10.0
# 2        Fullmetal Alchemist: Brotherhood     TV         Manga      64.0
# 3      Chainsaw Man – The Movie: Reze Arc  Movie         Manga       1.0
# 4                             Steins;Gate     TV  Visual novel      24.0
#
#              status  airing                          rating  score  scored_by  \
# 0   Finished Airing   False       PG-13 - Teens 13 or older   9.28     823434
# 1  Currently Airing    True       PG-13 - Teens 13 or older   9.16      62148
# 2   Finished Airing   False  R - 17+ (violence & profanity)   9.11    2290193
# 3   Finished Airing   False  R - 17+ (violence & profanity)   9.09     255607
# 4   Finished Airing   False       PG-13 - Teens 13 or older   9.07    1508032
#
#    rank  popularity  members  favorites  \
# 0   1.0         108  1353494      85889
# 1   2.0         644   414180       5476
# 2   3.0           3  3645704     240910
# 3   4.0         643   414906      12097
# 4   5.0          14  2786505     201170
#
#                                             synopsis    year  \
# 0  During their decade-long quest to defeat the D...  2023.0
# 1  Following the First-Class Mage Exam, the trio—...  2026.0
# 2  After a horrific alchemy experiment goes wrong...  2009.0
# 3  Despite the immediate challenges following bec...     NaN
# 4  Eccentric scientist Rintarou Okabe has a never...  2011.0
#
#                               genres    studios  \
# 0          Adventure, Drama, Fantasy   Madhouse
# 1          Adventure, Drama, Fantasy   Madhouse
# 2  Action, Adventure, Drama, Fantasy      Bones
# 3                    Action, Fantasy      MAPPA
# 4            Drama, Sci-Fi, Suspense  White Fox
#
#                                                  url
# 0  https://myanimelist.net/anime/52991/Sousou_no_...
# 1  https://myanimelist.net/anime/59978/Sousou_no_...
# 2  https://myanimelist.net/anime/5114/Fullmetal_A...
# 3  https://myanimelist.net/anime/57555/Chainsaw_M...
# 4     https://myanimelist.net/anime/9253/Steins_Gate

# %% [markdown]
# # Regression

# %% [markdown]
# When the target variable is a numerical variable then we refer to this task as a regression task.
#
# Examples of regression tasks:
# - Predict the price people are willing to pay for a house.
# - Predict the salary a student will earn in the future.
#
# Examples of machine learning algorithms that we could use for regression:
# - Linear regression
# - Decision trees
# - Random forests
# - Neural networks

# %%
iris.corr(numeric_only=True) # to find out which features  correlate with sepal_length
iris.head
# Out:
# <bound method NDFrame.head of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
features= ['petal_length'] # add 'petal_width' ('species' does not work; categorical is not implemented in DT of sciki learn)
dt_regression = DecisionTreeRegressor(max_depth = 2) # Increase max_depth to see effect in the plot
dt_regression.fit(iris_train[features].values, iris_train['sepal_length'].values)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
#visualisation in a scatterplot how a decision tree regressor makes his decisions
import matplotlib.pyplot as plt

X_train=iris_train[features].values                     # Assign matrix X
y_train=iris_train['sepal_length'].values               # Assign matrix y

sort_idx = X_train.flatten().argsort()                  # Sort X and y by ascending values of X
X_train = X_train[sort_idx]
y_train = y_train[sort_idx]

plt.figure(figsize=(16, 8))
plt.scatter(X_train, y_train, c='steelblue',                  # Plot actual target against features
            edgecolor='white', s=70)
plt.plot(X_train, dt_regression.predict(X_train),                      # Plot predicted target against features
         color='red', lw=2)
plt.xlabel('petal_length')
plt.ylabel('sepal_length')
plt.show()

# %%
pip install dtreeviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: dtreeviz in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (2.3.2)
# Requirement already satisfied: graphviz>=0.9 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from dtreeviz) (0.21)
# Requirement already satisfied: pandas in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from dtreeviz) (3.0.2)
# Requirement already satisfied: numpy in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from dtreeviz) (2.4.4)
# Requirement already satisfied: scikit-learn in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from dtreeviz) (1.8.0)
# Requirement already satisfied: matplotlib in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from dtreeviz) (3.10.8)
# Requirement already satisfied: colour in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from dtreeviz) (0.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib->dtreeviz) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib->dtreeviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib->dtreeviz) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib->dtreeviz) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib->dtreeviz) (26.1)
# Requirement already satisfied: pillow>=8 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib->dtreeviz) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib->dtreeviz) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib->dtreeviz) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.17.0)
# Requirement already satisfied: tzdata in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pandas->dtreeviz) (2026.1)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from scikit-learn->dtreeviz) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from scikit-learn->dtreeviz) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from scikit-learn->dtreeviz) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import dtreeviz
viz_rmodel = dtreeviz.model(dt_regression, X_train, y_train,
                            feature_names=features,
                            target_name='sepal_length')
viz_rmodel.rtree_feature_space(features=features)

# %%
from sklearn import tree
import graphviz

def plot_tree_regression(model, features):
    # Generate plot data
    dot_data = tree.export_graphviz(model, out_file=None, 
                          feature_names=features,  
                          filled=True, rounded=True,  
                          special_characters=True)  

    # Turn into graph using graphviz
    graph = graphviz.Source(dot_data)  

    # Write out a pdf
    graph.render("decision_tree")

    # Display in the notebook
    return graph

# %%
plot_tree_regression(dt_regression, features)

# %% [markdown]
# ## Evaluating the model

# %% [markdown]
# ![](https://docs.oracle.com/en/cloud/saas/freeform/ffuuu/img/insights_rmse_formula.jpg)

# %%
def calculate_rmse(predictions, actuals):
    if(len(predictions) != len(actuals)):
        raise Exception("The amount of predictions did not equal the amount of actuals")
    
    return (((predictions - actuals) ** 2).sum() / len(actuals)) ** (1/2)

# %%
predictionsOnTrainset = dt_regression.predict(iris_train[features])
predictionsOnTestset = dt_regression.predict(iris_test[features])

rmseTrain = calculate_rmse(predictionsOnTrainset, iris_train.sepal_length)
rmseTest = calculate_rmse(predictionsOnTestset, iris_test.sepal_length)

print("RMSE on training set " + str(rmseTrain))
print("RMSE on test set " + str(rmseTest))
# Out:
# RMSE on training set 0.3532245632130724
# RMSE on test set 0.461622721475121
# C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\validation.py:2684: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
# C:\Users\stein\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\validation.py:2684: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names

# %% [markdown]
# ✅ How to interpret this:
# Root Mean Squared Error (RMSE) gives the average prediction error in the same units as your target variable (here: sepal_length, measured in cm).
#
# An RMSE of ~0.46 cm means your model's average error on the test set is less than half a centimeter — quite acceptable, given that sepal_length values range roughly between 4.3 and 7.9 cm in the Iris dataset.
#
# The small gap between train and test RMSE also indicates low overfitting and good generalization.
#
# 📌 Rule of thumb:
# To judge whether RMSE is "good", compare it to:
#
# The range or standard deviation of the target variable.
# A baseline model, like predicting the mean sepal length for every sample.

# %% [markdown]
# ## Portfolio assignment 17
# 30 min: Train a decision tree to predict the body_mass_g of a penguin based on their characteristics.
# - Split the penguin dataset into a train (70%) and test (30%) set.
# - Use the train set to fit a DecisionTreeRegressor. You are free to to choose which columns you want to use as feature variables and you are also free to choose the max_depth of the tree.
# <b>Note</b>: Some machine learning algorithms can not handle missing values. You will either need to
#      - replace missing values (with the mean or most popular value). For replacing missing values you can use .fillna(\<value\>) https://pandas.pydata.org/docs/reference/api/pandas.Series.fillna.html
#      - remove rows with missing data.  You can remove rows with missing data with .dropna() https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html
# - Use your decision tree model to make predictions for both the train and test set.<br>
# <br>
#
# ![](https://i.imgur.com/0v1CGNV.png)<br>
# - Which depth and features did you add per cycle?
# - Calculate the RMSE for both the train set predictions and test set predictions.
# - Is the RMSE different? Did you expect this difference?
# - Use the plot_tree_regression function above to create a plot of the decision tree. Take a few minutes to analyse the decision tree. Do you understand the tree?<br>
# <br>
#
# Findings: ...

# %%
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# ## Portfolio assignment 18
# 30 min: Train a decision tree to predict one of the numerical columns of your own dataset.
# - Split your dataset into a train (70%) and test (30%) set.
# - Use the train set to fit a DecisionTreeRegressor. You are free to to choose which columns you want to use as feature variables and you are also free to choose the max_depth of the tree.
# - Use your decision tree model to make predictions for both the train and test set.<br>
# <br>
#
# ![](https://i.imgur.com/0v1CGNV.png)<br>
# - Which depth and features did you add per cycle?
# - Calculate the RMSE for both the train set predictions and test set predictions.
# - Is the RMSE different? Did you expect this difference?
# - Use the plot_tree_regression function above to create a plot of the decision tree. Take a few minutes to analyse the decision tree. Do you understand the tree?<br>
# <br>
#
# Findings: ...

# %%
import pandas as pd
topRatedAnime = pd.read_csv('top_anime_dataset.csv', sep=',')
topRatedAnime.head()
# Out:
#    mal_id                             title  \
# 0   52991                 Sousou no Frieren
# 1   59978      Sousou no Frieren 2nd Season
# 2    5114  Fullmetal Alchemist: Brotherhood
# 3   57555      Chainsaw Man Movie: Reze-hen
# 4    9253                       Steins;Gate
#
#                             title_english   type        source  episodes  \
# 0           Frieren: Beyond Journey's End     TV         Manga      28.0
# 1  Frieren: Beyond Journey's End Season 2     TV         Manga      10.0
# 2        Fullmetal Alchemist: Brotherhood     TV         Manga      64.0
# 3      Chainsaw Man – The Movie: Reze Arc  Movie         Manga       1.0
# 4                             Steins;Gate     TV  Visual novel      24.0
#
#              status  airing                          rating  score  scored_by  \
# 0   Finished Airing   False       PG-13 - Teens 13 or older   9.28     823434
# 1  Currently Airing    True       PG-13 - Teens 13 or older   9.16      62148
# 2   Finished Airing   False  R - 17+ (violence & profanity)   9.11    2290193
# 3   Finished Airing   False  R - 17+ (violence & profanity)   9.09     255607
# 4   Finished Airing   False       PG-13 - Teens 13 or older   9.07    1508032
#
#    rank  popularity  members  favorites  \
# 0   1.0         108  1353494      85889
# 1   2.0         644   414180       5476
# 2   3.0           3  3645704     240910
# 3   4.0         643   414906      12097
# 4   5.0          14  2786505     201170
#
#                                             synopsis    year  \
# 0  During their decade-long quest to defeat the D...  2023.0
# 1  Following the First-Class Mage Exam, the trio—...  2026.0
# 2  After a horrific alchemy experiment goes wrong...  2009.0
# 3  Despite the immediate challenges following bec...     NaN
# 4  Eccentric scientist Rintarou Okabe has a never...  2011.0
#
#                               genres    studios  \
# 0          Adventure, Drama, Fantasy   Madhouse
# 1          Adventure, Drama, Fantasy   Madhouse
# 2  Action, Adventure, Drama, Fantasy      Bones
# 3                    Action, Fantasy      MAPPA
# 4            Drama, Sci-Fi, Suspense  White Fox
#
#                                                  url
# 0  https://myanimelist.net/anime/52991/Sousou_no_...
# 1  https://myanimelist.net/anime/59978/Sousou_no_...
# 2  https://myanimelist.net/anime/5114/Fullmetal_A...
# 3  https://myanimelist.net/anime/57555/Chainsaw_M...
# 4     https://myanimelist.net/anime/9253/Steins_Gate
